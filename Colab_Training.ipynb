# %% [markdown]
# # Phishing Detection Training on Google Colab
#
# ## 1. Upload Files

# %%
from google.colab import files
import os

print("=" * 50)
Step 1: Upload code zip file
=" * 50)
uploaded = files.upload()
for fn in uploaded.keys():
    print(f'User uploaded file "{fn}" ({len(uploaded[fn])} bytes)')

import zipfile
with zipfile.ZipFile(list(uploaded.keys())[0], 'r') as zip_ref:
    zip_ref.extractall()
print("\nCode extracted!")

# %%
print("=" * 50)
Step 2: Upload PhiUSIIL CSV file
=" * 50)
uploaded = files.upload()
for fn in uploaded.keys():
    print(f'User uploaded file "{fn}" ({len(uploaded[fn])} bytes)')

# Move CSV to correct location
import shutil
csv_file = list(uploaded.keys())[0]
shutil.move(csv_file, f"data/raw/{csv_file}")
print(f"\nMoved {csv_file} to data/raw/")

# %%
print("=" * 50)
Step 3: Install dependencies
=" * 50)
# !pip install -r requirements.txt

# %%
print("=" * 50)
Step 4: Check GPU
=" * 50)
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")

# %%
print("=" * 50)
Step 5: Run Training
=" * 50)
# Training with PhiUSIIL dataset
# !python main.py --dataset-mode phiussiil --epochs 20 --batch-size 128

# %%
print("=" * 50)
Step 6: Download trained model
=" * 50)
files.download("experiments/best_model_phiussiil.pt")
